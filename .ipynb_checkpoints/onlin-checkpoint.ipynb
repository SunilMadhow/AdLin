# %%
# %load_ext autoreload
# %autoreload 2
import expert
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline  
T = 1000

def doppler(x, epsilon):
    return np.sin(2 * np.pi * (1 + epsilon) / (x + epsilon))

X = np.linspace(0, T, T)/T

Y = doppler(abs(1 - X), 0.38) + np.random.normal(0, 0.05, T)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
E = expert.LinearExpert1d(1)
for t in range(4):
    E.predict(X[t], t)
    E.update(Y[t], t)

# %%
print(E.history_x)
print(E.history_y)
# Out:
# [0.0, 0.001001001001001001, 0.002002002002002002, 0.0030030030030030034]
# [0.046260848812778255, -0.010330467795595826, 0.016643534800881904, 0.014611375301465659]

# %%
plt.hold = False
#t = np.linspace(0,sim_steps,sim_steps)/sim_steps
plt.figure(num=1, figsize=(12,6), dpi=80, facecolor='w', edgecolor='k')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.plot(Y,linewidth=4)
plt.plot(np.array(E.predictions), linewidth = 4)
plt.tick_params(labelsize=20)
plt.title('Doppler function',fontsize=20)
#plt.savefig('doppler.pdf',bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Doppler function')

# %%
from flh import FLH

# %%
alg = FLH(15)

# %%
alg.run(X, Y)
# Out:
# W =  [[1, 0, 0, 0, 0]]
# W =  [[1, 0, 0, 0, 0], [0.5, 0.5, 0, 0, 0]]
# W =  [[1, 0, 0, 0, 0], [0.5, 0.5, 0, 0, 0], [0.33307534517229737, 0.3335913214943694, 0.3333333333333333, 0, 0]]
# W =  [[1, 0, 0, 0, 0], [0.5, 0.5, 0, 0, 0], [0.33307534517229737, 0.3335913214943694, 0.3333333333333333, 0, 0], [0.24926694485330594, 0.2504351743610957, 0.25029788078559834, 0.25, 0]]
# W =  [[1, 0, 0, 0, 0], [0.5, 0.5, 0, 0, 0], [0.33307534517229737, 0.3335913214943694, 0.3333333333333333, 0, 0], [0.24926694485330594, 0.2504351743610957, 0.25029788078559834, 0.25, 0], [0.19938660994267268, 0.2003082219741434, 0.2002822323744079, 0.20002293570877608, 0.2]]
# loss =  0.00668273319418878
# array([[1.        , 0.        , 0.        , 0.        , 0.        ],
#        [0.5       , 0.5       , 0.        , 0.        , 0.        ],
#        [0.33307535, 0.33359132, 0.33333333, 0.        , 0.        ],
#        [0.24926694, 0.25043517, 0.25029788, 0.25      , 0.        ],
#        [0.19938661, 0.20030822, 0.20028223, 0.20002294, 0.2       ]])

# %%
plt.hold = False
#t = np.linspace(0,sim_steps,sim_steps)/sim_steps
plt.figure(num=1, figsize=(12,6), dpi=80, facecolor='w', edgecolor='k')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.plot(Y,linewidth=4)
plt.plot(np.array(alg.predictions), linewidth = 4)
plt.tick_params(labelsize=20)
plt.title('Doppler function',fontsize=20)
#plt.savefig('doppler.pdf',bbox_inches='tight')
# Out:
# [0.19992764524047468, 0.19998072117748567, 0.20006868419943344, 0.20002294938260629, 0.2]
